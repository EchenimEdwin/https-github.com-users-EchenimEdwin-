# %% [markdown]
# <a href="https://colab.research.google.com/github/EchenimEdwin/https-github.com-users-EchenimEdwin-/blob/main/SCADA_System_with_AI_ML_Integration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import random
from collections import deque # For storing recent data

# --- Configuration Parameters ---
# Sensor data limits
TEMP_MIN, TEMP_MAX = 20.0, 30.0
PRESSURE_MIN, PRESSURE_MAX = 50.0, 70.0
FLOW_MIN, FLOW_MAX = 100.0, 150.0

# Alarm thresholds
TEMP_ALARM_HIGH = 28.0
PRESSURE_ALARM_HIGH = 65.0
FLOW_ALARM_LOW = 110.0

# Data history for AI/ML (e.g., last 10 readings)
HISTORY_LENGTH = 10

# --- Global Data Storage ---
sensor_data_history = {
    'temperature': deque(maxlen=HISTORY_LENGTH),
    'pressure': deque(maxlen=HISTORY_LENGTH),
    'flow': deque(maxlen=HISTORY_LENGTH),
}
current_alarms = set() # Stores active alarm messages

# --- 1. Data Generation Function ---
def generate_sensor_data():
    """Simulates real-time sensor data with some fluctuations."""
    temp = round(random.uniform(TEMP_MIN, TEMP_MAX) + random.gauss(0, 1), 2)
    pressure = round(random.uniform(PRESSURE_MIN, PRESSURE_MAX) + random.gauss(0, 0.5), 2)
    flow = round(random.uniform(FLOW_MIN, FLOW_MAX) + random.gauss(0, 2), 2)

    # Introduce occasional "faults" for testing alarm/AI
    if random.random() < 0.1: # 10% chance of a fault
        fault_type = random.choice(['temp_spike', 'pressure_drop', 'flow_surge'])
        if fault_type == 'temp_spike':
            temp = round(random.uniform(TEMP_ALARM_HIGH + 1, TEMP_MAX + 5), 2)
        elif fault_type == 'pressure_drop':
            pressure = round(random.uniform(PRESSURE_MIN - 5, PRESSURE_ALARM_HIGH - 1), 2)
        elif fault_type == 'flow_surge':
            flow = round(random.uniform(FLOW_MIN - 10, FLOW_ALARM_LOW - 1), 2)

    return {'temperature': temp, 'pressure': pressure, 'flow': flow}

# --- 2. Data Visualization Function (Text-based SCADA Dashboard) ---
def display_dashboard(data, alarms, ai_insight):
    """
    Prints a simple text-based SCADA dashboard.
    Clears the console for a 'real-time' effect.
    """
    # For a real application, you'd use a GUI library like Tkinter, PyQt, or a web framework.
    # This simulates clearing the screen in a terminal.
    # print("\033c", end="") # Clear console - might not work on all terminals

    print("-" * 50)
    print(f"SCADA SYSTEM DASHBOARD - {time.strftime('%Y-%m-%d %H:%M:%S')}")
    print("-" * 50)

    print("\n--- Sensor Readings ---")
    for sensor, value in data.items():
        print(f"  {sensor.capitalize():<12}: {value:>8.2f}")

    print("\n--- Active Alarms ---")
    if alarms:
        for alarm in sorted(list(alarms)):
            print(f"  [!!!] {alarm}")
    else:
        print("  No active alarms.")

    print("\n--- AI/ML Insight ---")
    print(f"  {ai_insight}")

    print("-" * 50)
    print("\n") # Add some space before the next update

# --- 3. Alarm Triggering Function ---
def check_alarms(data):
    """
    Checks sensor data against predefined thresholds and updates active alarms.
    """
    new_alarms = set()

    if data['temperature'] > TEMP_ALARM_HIGH:
        new_alarms.add(f"High Temperature: {data['temperature']:.2f}°C (Threshold: >{TEMP_ALARM_HIGH}°C)")
    else:
        current_alarms.discard(f"High Temperature: {data['temperature']:.2f}°C (Threshold: >{TEMP_ALARM_HIGH}°C)") # Remove if cleared

    if data['pressure'] > PRESSURE_ALARM_HIGH:
        new_alarms.add(f"High Pressure: {data['pressure']:.2f} PSI (Threshold: >{PRESSURE_ALARM_HIGH} PSI)")
    else:
        current_alarms.discard(f"High Pressure: {data['pressure']:.2f} PSI (Threshold: >{PRESSURE_ALARM_HIGH} PSI)")

    if data['flow'] < FLOW_ALARM_LOW:
        new_alarms.add(f"Low Flow Rate: {data['flow']:.2f} L/s (Threshold: <{FLOW_ALARM_LOW} L/s)")
    else:
        current_alarms.discard(f"Low Flow Rate: {data['flow']:.2f} L/s (Threshold: <{FLOW_ALARM_LOW} L/s)")

    # Update global alarms set
    current_alarms.update(new_alarms)

# --- 4. AI/ML Model Integration (Simulated) ---
def analyze_with_ai_ml(data_history):
    """
    Simulates an AI/ML model analyzing historical and current data.
    In a real scenario, this would involve trained models (e.g., TensorFlow, PyTorch).
    For this example, it's a simple rule-based anomaly detection.
    """
    latest_temp = data_history['temperature'][-1] if data_history['temperature'] else None
    latest_pressure = data_history['pressure'][-1] if data_history['pressure'] else None
    latest_flow = data_history['flow'][-1] if data_history['flow'] else None

    # Simple anomaly detection: check for sudden large changes
    insight = "System operating normally."

    if len(data_history['temperature']) >= 2:
        temp_diff = latest_temp - data_history['temperature'][-2]
        if abs(temp_diff) > 3.0: # Significant change
            insight = "AI Alert: Unusual temperature fluctuation detected!"
            if temp_diff > 0: insight += f" (Rising by {temp_diff:.2f}°C)"
            else: insight += f" (Falling by {abs(temp_diff):.2f}°C)"
            return insight

    if len(data_history['pressure']) >= 2:
        pressure_diff = latest_pressure - data_history['pressure'][-2]
        if abs(pressure_diff) > 2.0:
            insight = "AI Alert: Sudden pressure change detected!"
            if pressure_diff > 0: insight += f" (Rising by {pressure_diff:.2f} PSI)"
            else: insight += f" (Falling by {abs(pressure_diff):.2f} PSI)"
            return insight

    if len(data_history['flow']) >= 2:
        flow_diff = latest_flow - data_history['flow'][-2]
        if abs(flow_diff) > 5.0:
            insight = "AI Alert: Significant flow rate deviation detected!"
            if flow_diff > 0: insight += f" (Rising by {flow_diff:.2f} L/s)"
            else: insight += f" (Falling by {abs(flow_diff):.2f} L/s)"
            return insight

    # Check for sustained out-of-norm behavior not necessarily an 'alarm' but potentially problematic
    if all(t > TEMP_ALARM_HIGH - 1 for t in list(data_history['temperature'])) and len(data_history['temperature']) == HISTORY_LENGTH:
        insight = "AI Suggestion: Sustained high temperature readings, consider inspection."
        return insight

    if all(f < FLOW_ALARM_LOW + 5 for f in list(data_history['flow'])) and len(data_history['flow']) == HISTORY_LENGTH:
        insight = "AI Suggestion: Flow rate consistently low, investigate potential blockage."
        return insight


    return insight


# --- Main SCADA Loop ---
def run_scada_system(duration_seconds=60, update_interval_seconds=2):
    """
    Runs the simulated SCADA system for a specified duration.
    """
    print("Starting SCADA System Simulation...")
    start_time = time.time()

    while (time.time() - start_time) < duration_seconds:
        # 1. Generate new data
        new_data = generate_sensor_data()

        # Update data history for AI/ML
        for sensor, value in new_data.items():
            sensor_data_history[sensor].append(value)

        # 2. Check for alarms
        check_alarms(new_data)

        # 3. Get AI/ML insight (only if enough data is available)
        ai_insight = "Waiting for sufficient data for AI analysis..."
        if all(len(history) == HISTORY_LENGTH for history in sensor_data_history.values()):
            ai_insight = analyze_with_ai_ml(sensor_data_history)

        # 4. Display dashboard
        display_dashboard(new_data, current_alarms, ai_insight)

        time.sleep(update_interval_seconds)

    print("\nSCADA System Simulation Finished.")
    print("Final Active Alarms:", current_alarms if current_alarms else "None")


if __name__ == "__main__":
    # Run the simulation for 120 seconds, updating every 2 seconds
    run_scada_system(duration_seconds=120, update_interval_seconds=2)
# Out:
# Starting SCADA System Simulation...
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:38:36
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    22.29
#   Pressure    :    67.83
#   Flow        :    96.65
#
# --- Active Alarms ---
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   Waiting for sufficient data for AI analysis...
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:38:38
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    21.16
#   Pressure    :    62.41
#   Flow        :   136.13
#
# --- Active Alarms ---
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   Waiting for sufficient data for AI analysis...
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:38:40
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    28.77
#   Pressure    :    49.92
#   Flow        :   137.18
#
# --- Active Alarms ---
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   Waiting for sufficient data for AI analysis...
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:38:42
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    23.73
#   Pressure    :    61.91
#   Flow        :   136.16
#
# --- Active Alarms ---
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   Waiting for sufficient data for AI analysis...
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:38:44
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    19.34
#   Pressure    :    55.23
#   Flow        :   103.28
#
# --- Active Alarms ---
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   Waiting for sufficient data for AI analysis...
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:38:46
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    26.02
#   Pressure    :    69.90
#   Flow        :   104.10
#
# --- Active Alarms ---
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   Waiting for sufficient data for AI analysis...
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:38:48
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    25.66
#   Pressure    :    62.82
#   Flow        :   125.58
#
# --- Active Alarms ---
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   Waiting for sufficient data for AI analysis...
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:38:50
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    20.93
#   Pressure    :    56.60
#   Flow        :   145.28
#
# --- Active Alarms ---
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   Waiting for sufficient data for AI analysis...
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:38:52
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    24.92
#   Pressure    :    69.90
#   Flow        :   137.32
#
# --- Active Alarms ---
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   Waiting for sufficient data for AI analysis...
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:38:54
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    28.68
#   Pressure    :    50.15
#   Flow        :   117.32
#
# --- Active Alarms ---
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Unusual temperature fluctuation detected! (Rising by 3.76°C)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:38:56
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    19.95
#   Pressure    :    66.60
#   Flow        :   102.36
#
# --- Active Alarms ---
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Unusual temperature fluctuation detected! (Falling by 8.73°C)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:38:58
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    29.83
#   Pressure    :    55.96
#   Flow        :   130.85
#
# --- Active Alarms ---
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Unusual temperature fluctuation detected! (Rising by 9.88°C)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:00
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    26.65
#   Pressure    :    54.07
#   Flow        :   133.78
#
# --- Active Alarms ---
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Unusual temperature fluctuation detected! (Falling by 3.18°C)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:02
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    22.66
#   Pressure    :    68.56
#   Flow        :   106.14
#
# --- Active Alarms ---
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Unusual temperature fluctuation detected! (Falling by 3.99°C)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:04
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    21.51
#   Pressure    :    59.94
#   Flow        :   130.99
#
# --- Active Alarms ---
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Sudden pressure change detected! (Falling by 8.62 PSI)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:06
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    28.30
#   Pressure    :    60.68
#   Flow        :   138.11
#
# --- Active Alarms ---
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Unusual temperature fluctuation detected! (Rising by 6.79°C)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:08
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    28.55
#   Pressure    :    65.98
#   Flow        :   119.11
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Sudden pressure change detected! (Rising by 5.30 PSI)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:10
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    24.38
#   Pressure    :    53.64
#   Flow        :   129.64
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Unusual temperature fluctuation detected! (Falling by 4.17°C)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:12
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    22.58
#   Pressure    :    54.11
#   Flow        :   115.76
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Significant flow rate deviation detected! (Falling by 13.88 L/s)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:14
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    21.37
#   Pressure    :    60.14
#   Flow        :   116.31
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Sudden pressure change detected! (Rising by 6.03 PSI)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:16
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    25.04
#   Pressure    :    50.78
#   Flow        :   134.58
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Unusual temperature fluctuation detected! (Rising by 3.67°C)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:18
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    23.08
#   Pressure    :    53.52
#   Flow        :   113.18
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Sudden pressure change detected! (Rising by 2.74 PSI)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:20
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    28.44
#   Pressure    :    52.07
#   Flow        :    98.97
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.44°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 98.97 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Unusual temperature fluctuation detected! (Rising by 5.36°C)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:22
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    20.22
#   Pressure    :    54.71
#   Flow        :   111.95
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.44°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 98.97 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Unusual temperature fluctuation detected! (Falling by 8.22°C)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:24
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    26.05
#   Pressure    :    64.99
#   Flow        :   116.58
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.44°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 98.97 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Unusual temperature fluctuation detected! (Rising by 5.83°C)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:26
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    27.44
#   Pressure    :    59.70
#   Flow        :   102.33
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.44°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 102.33 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 98.97 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Sudden pressure change detected! (Falling by 5.29 PSI)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:28
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    29.77
#   Pressure    :    56.03
#   Flow        :   136.75
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.44°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 102.33 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 98.97 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Sudden pressure change detected! (Falling by 3.67 PSI)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:30
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    25.36
#   Pressure    :    66.79
#   Flow        :   118.54
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.79 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.44°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 102.33 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 98.97 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Unusual temperature fluctuation detected! (Falling by 4.41°C)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:32
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    22.47
#   Pressure    :    53.05
#   Flow        :   100.46
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.79 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.44°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 100.46 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.33 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 98.97 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Sudden pressure change detected! (Falling by 13.74 PSI)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:34
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    24.75
#   Pressure    :    56.38
#   Flow        :   136.87
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.79 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.44°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 100.46 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.33 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 98.97 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Sudden pressure change detected! (Rising by 3.33 PSI)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:36
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    30.78
#   Pressure    :    53.12
#   Flow        :   140.23
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.79 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.44°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 30.78°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 100.46 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.33 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 98.97 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Unusual temperature fluctuation detected! (Rising by 6.03°C)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:38
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    21.62
#   Pressure    :    57.89
#   Flow        :    96.44
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.79 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.44°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 30.78°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 100.46 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.33 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.44 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 98.97 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Unusual temperature fluctuation detected! (Falling by 9.16°C)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:40
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    28.42
#   Pressure    :    65.50
#   Flow        :   142.60
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.50 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.79 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.42°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.44°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 30.78°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 100.46 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.33 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.44 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 98.97 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Unusual temperature fluctuation detected! (Rising by 6.80°C)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:42
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    21.49
#   Pressure    :    54.39
#   Flow        :   116.45
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.50 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.79 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.42°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.44°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 30.78°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 100.46 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.33 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.44 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 98.97 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Unusual temperature fluctuation detected! (Falling by 6.93°C)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:44
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    25.80
#   Pressure    :    59.15
#   Flow        :   147.88
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.50 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.79 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.42°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.44°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 30.78°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 100.46 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.33 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.44 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 98.97 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Unusual temperature fluctuation detected! (Rising by 4.31°C)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:46
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    20.12
#   Pressure    :    62.53
#   Flow        :   116.77
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.50 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.79 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.42°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.44°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 30.78°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 100.46 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.33 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.44 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 98.97 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Unusual temperature fluctuation detected! (Falling by 5.68°C)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:48
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    21.02
#   Pressure    :    65.37
#   Flow        :   141.76
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.37 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 65.50 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.79 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.42°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.44°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 30.78°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 100.46 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.33 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.44 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 98.97 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Sudden pressure change detected! (Rising by 2.84 PSI)
# --------------------------------------------------
#
#
# --------------------------------------------------
# SCADA SYSTEM DASHBOARD - 2025-06-21 23:39:50
# --------------------------------------------------
#
# --- Sensor Readings ---
#   Temperature :    29.86
#   Pressure    :    58.11
#   Flow        :   142.07
#
# --- Active Alarms ---
#   [!!!] High Pressure: 65.37 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 65.50 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 65.98 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.60 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 66.79 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 67.83 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 68.56 PSI (Threshold: >65.0 PSI)
#   [!!!] High Pressure: 69.90 PSI (Threshold: >65.0 PSI)
#   [!!!] High Temperature: 28.30°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.42°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.44°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.55°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.68°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 28.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.77°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.83°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 29.86°C (Threshold: >28.0°C)
#   [!!!] High Temperature: 30.78°C (Threshold: >28.0°C)
#   [!!!] Low Flow Rate: 100.46 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.33 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 102.36 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 103.28 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 104.10 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 106.14 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.44 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 96.65 L/s (Threshold: <110.0 L/s)
#   [!!!] Low Flow Rate: 98.97 L/s (Threshold: <110.0 L/s)
#
# --- AI/ML Insight ---
#   AI Alert: Unusual temperature fluctuation detected! (Rising by 8.84°C)
# --------------------------------------------------
