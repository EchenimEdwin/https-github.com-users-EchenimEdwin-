# %% [markdown]
# <a href="https://colab.research.google.com/github/EchenimEdwin/https-github.com-users-EchenimEdwin-/blob/main/Smart_Pipeline_Monitoring_and_Leak_Detection_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import time
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# Thresholds for anomaly detection
PRESSURE_THRESHOLD = 20  # Example: Minimum safe pressure (in PSI)
TEMPERATURE_THRESHOLD = 100  # Example: Maximum safe temperature (in °C)
FLOW_RATE_THRESHOLD = 30  # Example: Minimum safe flow rate (in Liters/Second)

# Simulated IoT sensors data for multiple pipeline nodes
def simulate_sensor_data():
    return {
        "pressure": random.uniform(15, 50),  # Simulate pressure in PSI
        "temperature": random.uniform(20, 120),  # Simulate temperature in °C
        "flow_rate": random.uniform(10, 50),  # Simulate flow rate in L/s
    }

# Anomaly detection function
def detect_anomalies(sensor_data):
    anomalies = []
    if sensor_data["pressure"] < PRESSURE_THRESHOLD:
        anomalies.append("Low Pressure Detected")
    if sensor_data["temperature"] > TEMPERATURE_THRESHOLD:
        anomalies.append("High Temperature Detected")
    if sensor_data["flow_rate"] < FLOW_RATE_THRESHOLD:
        anomalies.append("Low Flow Rate Detected")
    return anomalies

# Send alert via email (SMTP example)
def send_alert(subject, message):
    try:
        sender_email = "your_email@example.com"
        receiver_email = "receiver_email@example.com"
        password = "your_email_password"  # Use a secure method to store passwords!

        # Email setup
        msg = MIMEMultipart()
        msg['From'] = sender_email
        msg['To'] = receiver_email
        msg['Subject'] = subject
        msg.attach(MIMEText(message, 'plain'))

        # Connect to email server (using Gmail SMTP as an example)
        server = smtplib.SMTP('smtp.gmail.com', 587)
        server.starttls()
        server.login(sender_email, password)
        text = msg.as_string()
        server.sendmail(sender_email, receiver_email, text)
        server.quit()
        print("Alert sent successfully!")
    except Exception as e:
        print(f"Failed to send alert: {e}")

# SCADA-like monitoring system
def monitor_pipeline():
    print("Starting Pipeline Monitoring System...")
    while True:
        # Simulate data collection from IoT sensors
        sensor_data = simulate_sensor_data()
        print("\n[Sensor Data]")
        print(f"Pressure: {sensor_data['pressure']} PSI")
        print(f"Temperature: {sensor_data['temperature']} °C")
        print(f"Flow Rate: {sensor_data['flow_rate']} L/s")

        # Detect anomalies
        anomalies = detect_anomalies(sensor_data)
        if anomalies:
            print("\n[ALERT] Anomalies Detected!")
            for anomaly in anomalies:
                print(f"- {anomaly}")

            # Send alert
            alert_message = f"Pipeline Anomalies Detected:\n\n" + "\n".join(anomalies)
            send_alert("Pipeline Alert", alert_message)
        else:
            print("\n[Status] Pipeline is operating normally.")

        # Wait before checking again
        time.sleep(5)  # Simulate real-time monitoring (5-second intervals)

# Start monitoring
if __name__ == "__main__":
    monitor_pipeline()
# Out:
# Starting Pipeline Monitoring System...
#
# [Sensor Data]
# Pressure: 22.50143904327892 PSI
# Temperature: 81.37362007278016 °C
# Flow Rate: 36.66715441918334 L/s
#
# [Status] Pipeline is operating normally.
#
# [Sensor Data]
# Pressure: 34.269468845163786 PSI
# Temperature: 33.02804639844991 °C
# Flow Rate: 28.685304236910063 L/s
#
# [ALERT] Anomalies Detected!
# - Low Flow Rate Detected
# Failed to send alert: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d2e1a72fcca58-749b5e08e2fsm220357b3a.19 - gsmtp')
#
# [Sensor Data]
# Pressure: 41.59575450271883 PSI
# Temperature: 91.11835664456572 °C
# Flow Rate: 49.45044693369902 L/s
#
# [Status] Pipeline is operating normally.
#
# [Sensor Data]
# Pressure: 49.95940024662969 PSI
# Temperature: 101.59186123354958 °C
# Flow Rate: 23.544394240304353 L/s
#
# [ALERT] Anomalies Detected!
# - High Temperature Detected
# - Low Flow Rate Detected
# Failed to send alert: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d9443c01a7336-237d8609209sm95870225ad.110 - gsmtp')
#
# [Sensor Data]
# Pressure: 35.61959122278848 PSI
# Temperature: 44.62125871524875 °C
# Flow Rate: 29.856651275117486 L/s
#
# [ALERT] Anomalies Detected!
# - Low Flow Rate Detected
# Failed to send alert: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d2e1a72fcca58-749c8851337sm199761b3a.126 - gsmtp')
#
# [Sensor Data]
# Pressure: 46.636738295349566 PSI
# Temperature: 101.84543627354303 °C
# Flow Rate: 19.084869239615564 L/s
#
# [ALERT] Anomalies Detected!
# - High Temperature Detected
# - Low Flow Rate Detected
# Failed to send alert: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d2e1a72fcca58-749c8871954sm207105b3a.149 - gsmtp')
#
# [Sensor Data]
# Pressure: 24.294400838111443 PSI
# Temperature: 42.756570869390856 °C
# Flow Rate: 26.43305319106403 L/s
#
# [ALERT] Anomalies Detected!
# - Low Flow Rate Detected
# Failed to send alert: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials 98e67ed59e1d1-3159de7c703sm9938980a91.0 - gsmtp')
#
# [Sensor Data]
# Pressure: 19.517163855889926 PSI
# Temperature: 54.74157705386809 °C
# Flow Rate: 19.705680054652653 L/s
#
# [ALERT] Anomalies Detected!
# - Low Pressure Detected
# - Low Flow Rate Detected
# Failed to send alert: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d9443c01a7336-237d866b5d3sm94226745ad.164 - gsmtp')
#
# [Sensor Data]
# Pressure: 26.78956135273532 PSI
# Temperature: 42.678810843658766 °C
# Flow Rate: 42.22141687324765 L/s
#
# [Status] Pipeline is operating normally.
#
# [Sensor Data]
# Pressure: 36.00737275339049 PSI
# Temperature: 115.88973819463354 °C
# Flow Rate: 20.745813985057964 L/s
#
# [ALERT] Anomalies Detected!
# - High Temperature Detected
# - Low Flow Rate Detected
# Failed to send alert: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials 98e67ed59e1d1-315cdf95ab3sm223727a91.0 - gsmtp')
#
# [Sensor Data]
# Pressure: 26.88723547050656 PSI
# Temperature: 24.81599145546775 °C
# Flow Rate: 12.794490252158806 L/s
#
# [ALERT] Anomalies Detected!
# - Low Flow Rate Detected
# Failed to send alert: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d9443c01a7336-237d870330fsm92131535ad.227 - gsmtp')
#
# [Sensor Data]
# Pressure: 27.427676180211293 PSI
# Temperature: 104.94284727733368 °C
# Flow Rate: 16.915325505609392 L/s
#
# [ALERT] Anomalies Detected!
# - High Temperature Detected
# - Low Flow Rate Detected
# Failed to send alert: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d2e1a72fcca58-749c882cedfsm221669b3a.90 - gsmtp')
#
# [Sensor Data]
# Pressure: 46.88129352289514 PSI
# Temperature: 75.43911672568066 °C
# Flow Rate: 19.783073722451956 L/s
#
# [ALERT] Anomalies Detected!
# - Low Flow Rate Detected
# Failed to send alert: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d2e1a72fcca58-749b5e08cf0sm235563b3a.10 - gsmtp')
#
# [Sensor Data]
# Pressure: 15.73906304192862 PSI
# Temperature: 52.123061404276854 °C
# Flow Rate: 41.05280176278295 L/s
#
# [ALERT] Anomalies Detected!
# - Low Pressure Detected
# Failed to send alert: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d2e1a72fcca58-749c8838750sm212400b3a.106 - gsmtp')
#
# [Sensor Data]
# Pressure: 32.54842061192362 PSI
# Temperature: 115.37660678078173 °C
# Flow Rate: 27.864827104373198 L/s
#
# [ALERT] Anomalies Detected!
# - High Temperature Detected
# - Low Flow Rate Detected
# Failed to send alert: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials 41be03b00d2f7-b31f118ecb2sm7536108a12.11 - gsmtp')
#
# [Sensor Data]
# Pressure: 48.956733003056456 PSI
# Temperature: 32.6065260378898 °C
# Flow Rate: 49.33565617063512 L/s
#
# [Status] Pipeline is operating normally.
#
# [Sensor Data]
# Pressure: 43.844994009593464 PSI
# Temperature: 88.31456829578876 °C
# Flow Rate: 17.52473549988471 L/s
#
# [ALERT] Anomalies Detected!
# - Low Flow Rate Detected
# Failed to send alert: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials 98e67ed59e1d1-315ac2991a7sm7018125a91.25 - gsmtp')
#
# [Sensor Data]
# Pressure: 21.442436337307456 PSI
# Temperature: 70.48170347996376 °C
# Flow Rate: 40.902182878514466 L/s
#
# [Status] Pipeline is operating normally.
#
# [Sensor Data]
# Pressure: 27.564696028633364 PSI
# Temperature: 119.06013457852687 °C
# Flow Rate: 18.50961375234172 L/s
#
# [ALERT] Anomalies Detected!
# - High Temperature Detected
# - Low Flow Rate Detected
# Failed to send alert: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d9443c01a7336-237d8676123sm91569495ad.173 - gsmtp')
#
# [Sensor Data]
# Pressure: 28.87189686832223 PSI
# Temperature: 46.2548639572625 °C
# Flow Rate: 35.00316586589875 L/s
#
# [Status] Pipeline is operating normally.
#
# [Sensor Data]
# Pressure: 21.73799825351276 PSI
# Temperature: 61.515911680802375 °C
# Flow Rate: 12.641699984249293 L/s
#
# [ALERT] Anomalies Detected!
# - Low Flow Rate Detected
# Failed to send alert: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d2e1a72fcca58-749c8872113sm201807b3a.161 - gsmtp')
#
# [Sensor Data]
# Pressure: 36.47213531618675 PSI
# Temperature: 50.03737105047204 °C
# Flow Rate: 27.88437413636174 L/s
#
# [ALERT] Anomalies Detected!
# - Low Flow Rate Detected
# Failed to send alert: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d2e1a72fcca58-749c8850c9fsm219776b3a.109 - gsmtp')
#
# [Sensor Data]
# Pressure: 27.405021375456748 PSI
# Temperature: 34.71109823165819 °C
# Flow Rate: 18.402761299035415 L/s
#
# [ALERT] Anomalies Detected!
# - Low Flow Rate Detected
# Failed to send alert: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d9443c01a7336-237d86a3083sm92055915ad.195 - gsmtp')
#
# [Sensor Data]
# Pressure: 35.36496156452233 PSI
# Temperature: 119.10189922979919 °C
# Flow Rate: 36.197026766083994 L/s
#
# [ALERT] Anomalies Detected!
# - High Temperature Detected
# Failed to send alert: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d2e1a72fcca58-749c8872160sm215554b3a.152 - gsmtp')
#
# [Sensor Data]
# Pressure: 40.57181766203776 PSI
# Temperature: 72.74082272897112 °C
# Flow Rate: 42.26775794182962 L/s
#
# [Status] Pipeline is operating normally.
#
# [Sensor Data]
# Pressure: 41.403074165657685 PSI
# Temperature: 112.63199753293048 °C
# Flow Rate: 48.445851811941026 L/s
#
# [ALERT] Anomalies Detected!
# - High Temperature Detected
# Failed to send alert: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d2e1a72fcca58-749c88548ffsm208251b3a.134 - gsmtp')
#
# [Sensor Data]
# Pressure: 22.011821662007712 PSI
# Temperature: 98.71166118162007 °C
# Flow Rate: 42.654642159779705 L/s
#
# [Status] Pipeline is operating normally.
